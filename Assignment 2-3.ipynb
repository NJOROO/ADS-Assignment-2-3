# %%
import os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee = pd.read_csv('Employee.csv')

# %%
employee.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
employee.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
employee['DistanceFromHome']
# Out:
# 0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: DistanceFromHome, Length: 1470, dtype: int64

# %%
employee['JobRole']
# Out:
# 0                 Sales Executive
# 1              Research Scientist
# 2           Laboratory Technician
# 3              Research Scientist
# 4           Laboratory Technician
#                   ...
# 1465        Laboratory Technician
# 1466    Healthcare Representative
# 1467       Manufacturing Director
# 1468              Sales Executive
# 1469        Laboratory Technician
# Name: JobRole, Length: 1470, dtype: object

# %%
employee['Attrition']
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
data = employee['DistanceFromHome'] , employee['Attrition'], employee['JobRole']

  
print(data)
# Out:
# (0        1
# 1        8
# 2        2
# 3        3
# 4        2
#         ..
# 1465    23
# 1466     6
# 1467     4
# 1468     2
# 1469     8
# Name: DistanceFromHome, Length: 1470, dtype: int64, 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object, 0                 Sales Executive
# 1              Research Scientist
# 2           Laboratory Technician
# 3              Research Scientist
# 4           Laboratory Technician
#                   ...
# 1465        Laboratory Technician
# 1466    Healthcare Representative
# 1467       Manufacturing Director
# 1468              Sales Executive
# 1469        Laboratory Technician
# Name: JobRole, Length: 1470, dtype: object)

# %%
employee.groupby(['DistanceFromHome', 'JobRole', 'Attrition'])['Attrition'].count().unstack().reset_index()
# Out:
# Attrition  DistanceFromHome                    JobRole    No  Yes
# 0                         1  Healthcare Representative  23.0  NaN
# 1                         1            Human Resources   8.0  1.0
# 2                         1      Laboratory Technician  27.0  4.0
# 3                         1                    Manager  13.0  NaN
# 4                         1     Manufacturing Director  23.0  1.0
# ..                      ...                        ...   ...  ...
# 219                      29                    Manager   3.0  1.0
# 220                      29     Manufacturing Director   4.0  NaN
# 221                      29         Research Scientist   3.0  1.0
# 222                      29            Sales Executive   4.0  1.0
# 223                      29       Sales Representative   1.0  NaN
#
# [224 rows x 4 columns]

# %%
employee.Attrition
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
employee['JobRole'].nunique()
# Out:
# 9

# %%
employee.groupby(['JobRole']).sum().plot(
    kind='pie', y = 'DistanceFromHome' ,title='DistanceFromHome',autopct='%1.1f%%'
    #egend =['Attrition']
    #egend=['HealthCare Representative', 'Human Resources', 'Laboratory Technician', 'Manager','Manufacturing Director','Research Director','Research Scientist','Sales Executive','Sales Representative']
    ,figsize=(20,20))
# Out:
# <AxesSubplot:title={'center':'DistanceFromHome'}, ylabel='DistanceFromHome'>

# %%
employee.groupby(['Education', 'Attrition'])['MonthlyIncome'].mean()
# Out:
# Education  Attrition
# 1          No           5926.129496
#            Yes          4360.161290
# 2          No           6586.058824
#            Yes          4282.545455
# 3          No           6882.919662
#            Yes          4770.242424
# 4          No           7087.814706
#            Yes          5335.155172
# 5          No           8559.906977
#            Yes          5850.200000
# Name: MonthlyIncome, dtype: float64

# %%
plt.figure(figsize = (22, 12))

sns.barplot(x = 'Education', y = 'Attrition', data = employee, )
sns.barplot(x = 'MonthlyIncome', y = 'Attrition', data = employee,)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome', ylabel='Attrition'>
